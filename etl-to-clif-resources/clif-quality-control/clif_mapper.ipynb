# %% [markdown]
# ## CLIF Mapper
#
# An ML model to map your EHR data to CLIF mCIDE.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

# %%
#Enter the location for your CLIF-1.0 directory
root_location = '/Users/kavenchhikara/Desktop/CLIF-1.0'
organism_data_path = f"{root_location}/mCIDE/ucmc/clif_vocab_microbiology_organism_ucmc.csv"
fluid_data_path = f"{root_location}/mCIDE/ucmc/clif_vocab_microbiology_fluid_ucmc.csv"

# %%
# Load Data
organism_data = pd.read_csv(organism_data_path)

# %%
organism_data.head()
# Out:
#                                            ord_value           organism_name  \
# 0  ^acinetobacter baumanii for susceptibility res...  acinetobacter_baumanii
# 1  ^acinetobacter baumanii for susceptibility res...  acinetobacter_baumanii
# 2  ^acinetobacter baumanii in both antibiotic res...  acinetobacter_baumanii
# 3                      10,000 acinetobacter baumanii  acinetobacter_baumanii
# 4                  10,000 cgt acinetobacter baumanii  acinetobacter_baumanii
#
#                                    organism_category
# 0  acinetobacter (baumanii, calcoaceticus, lwoffi...
# 1  acinetobacter (baumanii, calcoaceticus, lwoffi...
# 2  acinetobacter (baumanii, calcoaceticus, lwoffi...
# 3  acinetobacter (baumanii, calcoaceticus, lwoffi...
# 4  acinetobacter (baumanii, calcoaceticus, lwoffi...

# %%
#Clean data
organism_data = organism_data.dropna(subset=['ord_value'])  # Remove rows with NaN in 'ord_value'

# %%
# Preprocess Data
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(organism_data['ord_value'])
y_organism = organism_data['organism_name']
y_category = organism_data['organism_category']

# %%
# Check Class Distribution
print(y_organism.value_counts())
# Out:
# staphylococcus_aureus        311
# pseudomonas_aeruginosa       238
# no growth                    125
# enterococcus_faecium         114
# enterococcus_faecalis        102
#                             ...
# chromobacterium_violaceum      1
# chryseobacterium_gleum         1
# bacteroides_massiliensis       1
# chryseobacterium_sp            1
# capnocytophaga_sputigena       1
# Name: organism_name, Length: 942, dtype: int64

# %%
print(y_category.value_counts())
# Out:
# other bacteria                                              477
# staphylococcus (coag +)                                     317
# enterococcus (all species)                                  306
# pseudomonas (all species except cepacia and maltophilia)    275
# streptococcus (all species except enterococcus)             200
#                                                            ...
# adenovirus                                                    1
# herpes zoster (chicken pox, varicella)                        1
# enterovirus (coxsackie, echo, polio)                          1
# cytomegalovirus (cmv)                                         1
# cryptosporidium                                               1
# Name: organism_category, Length: 74, dtype: int64

# %%
# Split Data
X_train, X_test, y_train, y_test = train_test_split(X, y_organism, test_size=0.2, random_state=42)

# %%
# Train Model
model = LogisticRegression()
model.fit(X_train, y_train)

# %%
# Predict
y_pred = model.predict(X_test)

# %%
results = classification_report(y_test, y_pred, zero_division=0)

# %%
# Evaluate
print(results)
# Out:
#                                                             precision    recall  f1-score   support
#
#                                             abiotrophia_sp       0.00      0.00      0.00         1
#                                achromobacter_denitrificans       0.00      0.00      0.00         1
#                                           achromobacter_sp       0.00      0.00      0.00         1
#                                 achromobacter_xylosoxidans       0.60      1.00      0.75         3
#                                         acidaminococcus_sp       0.00      0.00      0.00         1
#                                     acinetobacter_baumanii       0.78      1.00      0.88        14
#                                        acinetobacter_junii       0.00      0.00      0.00         1
#                                       acinetobacter_parvus       0.00      0.00      0.00         1
#                                           acinetobacter_sp       0.00      0.00      0.00         2
#                                          actinobacillus_sp       0.00      0.00      0.00         1
#                                          actinomyces_canis       0.00      0.00      0.00         1
#                                      actinomyces_europaeus       0.00      0.00      0.00         1
#                                  actinomyces_odontolyticus       0.00      0.00      0.00         1
#                                             actinomyces_sp       0.00      0.00      0.00         1
#                                       actinomyces_viscosus       0.00      0.00      0.00         1
#                                     actinotignum_sanguinis       0.00      0.00      0.00         1
#                                          aerococcus_urinae       0.00      0.00      0.00         2
#                                          aeromonas_jandaei       0.00      0.00      0.00         1
#                      aggregatibacter_actinomycetemcomitans       0.00      0.00      0.00         1
#                                aggregatibacter_aphrophilus       0.00      0.00      0.00         1
#                                         aggregatibacter_sp       0.00      0.00      0.00         1
#                                       alcaligenes_faecalis       0.00      0.00      0.00         1
#                                             alcaligenes_sp       0.00      0.00      0.00         1
#                                           alloscardovia_sp       0.00      0.00      0.00         1
#                                  anaerococcus_lactolyticus       0.00      0.00      0.00         1
#                                            arthrobacter_sp       0.00      0.00      0.00         1
#                                         aspergillus_flavus       0.00      0.00      0.00         1
#                                      aspergillus_fumigatus       0.00      0.00      0.00         1
#                                       aspergillus_nidulans       0.00      0.00      0.00         1
#                                             aspergillus_sp       0.00      0.00      0.00         2
#                                        aspergillus_sydowii       0.00      0.00      0.00         1
#                                        aspergillus_terreus       0.00      0.00      0.00         1
#                                         atopobium_parvulum       0.00      0.00      0.00         1
#                                    aureimonas_altamirensis       0.00      0.00      0.00         1
#                                            bacillus_cereus       0.00      0.00      0.00         1
#                                         bacillus_circulans       0.00      0.00      0.00         1
#                                           bacillus_pumilus       0.00      0.00      0.00         1
#                                                bacillus_sp       1.00      1.00      1.00         1
#                               bacteroides_cellulosilyticus       0.00      0.00      0.00         1
#                                      bacteroides_coagulans       0.00      0.00      0.00         1
#                                         bacteroides_faecis       0.00      0.00      0.00         1
#                                       bacteroides_fragilis       0.00      0.00      0.00         2
#                                   bacteroides_intestinalis       0.00      0.00      0.00         1
#                                   bacteroides_massiliensis       0.00      0.00      0.00         1
#                                             bacteroides_sp       0.00      0.00      0.00         1
#                               bacteroides_thetaiotaomicron       0.00      0.00      0.00         1
#                                      bacteroides_uniformis       0.00      0.00      0.00         1
#                                      bifidobacterium_breve       0.00      0.00      0.00         1
#                                          bordetella_hinzii       0.00      0.00      0.00         1
#                                          brevibacterium_sp       0.00      0.00      0.00         1
#                                        brucella_melitensis       0.00      0.00      0.00         1
#                                       burkholderia_cepacia       0.75      1.00      0.86         3
#                                      burkholderia_gladioli       0.00      0.00      0.00         1
#                                   burkholderia_multivorans       0.00      0.00      0.00         1
#                                            burkholderia_sp       0.00      0.00      0.00         1
#                                         campylobacter_coli       0.00      0.00      0.00         1
#                                        campylobacter_fetus       0.00      0.00      0.00         1
#                                   campylobacter_helveticus       0.00      0.00      0.00         1
#                                       campylobacter_jejuni       0.00      0.00      0.00         1
#                                           candida_albicans       0.57      1.00      0.73         8
#                                       candida_dubliniensis       1.00      0.50      0.67         2
#                                           candida_glabrata       1.00      1.00      1.00         3
#                                     candida_guilliermondii       0.00      0.00      0.00         1
#                                             candida_krusei       1.00      1.00      1.00         1
#                                        candida_nivariensis       0.00      0.00      0.00         1
#                                      candida_orthopsilosis       0.00      0.00      0.00         1
#                                       candida_parapsilosis       1.00      1.00      1.00         3
#                                         candida_pararugosa       0.00      0.00      0.00         1
#                                         candida_tropicalis       1.00      1.00      1.00         4
#                                   capnocytophaga_canimorus       0.00      0.00      0.00         1
#                                    cardiobacterium_hominis       0.00      0.00      0.00         1
#                                   carnobacterium_divergens       0.00      0.00      0.00         1
#                                       chryseomonas_luteola       0.00      0.00      0.00         1
#                                   citrobacter_amalonaticus       0.00      0.00      0.00         2
#                                       citrobacter_freundii       0.57      1.00      0.73         4
#                                         citrobacter_koseri       1.00      1.00      1.00         4
#                                        citrobacter_youngae       0.00      0.00      0.00         1
#                                   clostridioides_difficile       0.00      0.00      0.00         1
#                                      clostridium_butyricum       0.00      0.00      0.00         1
#                                clostridium_clostridioforme       0.00      0.00      0.00         1
#                                     clostridium_disporicum       0.00      0.00      0.00         1
#                                      clostridium_hathewayi       0.00      0.00      0.00         1
#                                             clostridium_sp       1.00      1.00      1.00         2
#                                     clostridium_sphenoides       0.00      0.00      0.00         1
#                             corynebacterium_argentoratense       0.00      0.00      0.00         1
#                                    corynebacterium_coyleae       0.00      0.00      0.00         1
#                                   corynebacterium_jeikeium       0.00      0.00      0.00         1
#                               corynebacterium_minutissimum       0.00      0.00      0.00         1
#                                 corynebacterium_propinquum       0.00      0.00      0.00         1
#                       corynebacterium_pseudodiphtheriticum       0.00      0.00      0.00         1
#                                         corynebacterium_sp       0.27      0.75      0.40         4
#                                   corynebacterium_striatum       0.00      0.00      0.00         1
#                         corynebacterium_tuberculostearicum       0.00      0.00      0.00         1
#                                    cyclospora_cayetanensis       0.00      0.00      0.00         1
#                                       debaromyces_hansenii       0.00      0.00      0.00         1
#                                           desulfovibrio_sp       0.00      0.00      0.00         1
#                                          eggerthella_lenta       0.00      0.00      0.00         1
#                             elizabethkingia_meningoseptica       0.00      0.00      0.00         2
#                                     enterobacter_aerogenes       0.90      1.00      0.95         9
#                                       enterobacter_cloacae       0.83      1.00      0.91        10
#                                            enterobacter_sp       0.00      0.00      0.00         2
#                                         enterococcus_avium       0.75      1.00      0.86         3
#                                 enterococcus_casseliflavus       1.00      0.50      0.67         2
#                                        enterococcus_durans       1.00      1.00      1.00         2
#                                      enterococcus_faecalis       0.96      1.00      0.98        27
#                                       enterococcus_faecium       0.94      1.00      0.97        17
#                                    enterococcus_gallinarum       1.00      1.00      1.00         1
#                                        enterococcus_gilvus       0.00      0.00      0.00         1
#                                    enterococcus_raffinosus       1.00      1.00      1.00         2
#                                            enterococcus_sp       0.50      0.50      0.50         2
#                                           escherichia_coli       0.75      0.90      0.82        20
#                                      escherichia_hermannii       0.00      0.00      0.00         1
#                                             escherichia_sp       0.00      0.00      0.00         1
#                                       escherichia_vulneris       0.00      0.00      0.00         1
#                                               exophiala_sp       0.00      0.00      0.00         1
#                                               facklamia_sp       0.00      0.00      0.00         1
#                                                fusarium_sp       0.00      0.00      0.00         1
#                               fusobacterium_gonidiaformans       0.00      0.00      0.00         1
#                                   fusobacterium_mortiferum       0.00      0.00      0.00         1
#                                  fusobacterium_necrophorum       0.00      0.00      0.00         1
#                                    fusobacterium_nucleatum       1.00      1.00      1.00         2
#                                fusobacterium_periodonticum       0.00      0.00      0.00         1
#                                          fusobacterium_spp       0.00      0.00      0.00         1
#                                          gemella_sanguinis       0.00      0.00      0.00         1
#                                                 gemella_sp       0.00      0.00      0.00         1
#                                                geomyces_sp       0.00      0.00      0.00         1
#                                       gordonia_bronchialis       0.00      0.00      0.00         1
#                                                gordonia_sp       0.00      0.00      0.00         2
#                                    gram negative rod (nos)       0.71      0.83      0.77         6
#                                  gram positive cocci (nos)       0.00      0.00      0.00         0
#                                    gram positive rod (nos)       0.00      0.00      0.00         0
#                                         grimontia_hollisae       0.00      0.00      0.00         2
#                                 haemophilus_parainfluenzae       0.00      0.00      0.00         1
#                                               hafnia_alvei       0.00      0.00      0.00         2
#                                             helcococcus_sp       0.00      0.00      0.00         1
#                                       hungatella_hathewayi       0.00      0.00      0.00         1
#                                              janibacter_sp       0.00      0.00      0.00         1
#                                       klebsiella_aerogenes       0.00      0.00      0.00         1
#                                         klebsiella_oxytoca       1.00      1.00      1.00         6
#                                      klebsiella_pneumoniae       1.00      1.00      1.00        15
#                                         kluyvera_georgiana       0.00      0.00      0.00         1
#                                         kocuria_rhizophila       0.00      0.00      0.00         1
#                                                 kocuria_sp       0.00      0.00      0.00         1
#                                          kosakonia_cowanii       0.00      0.00      0.00         1
#                                  lactobacillus_acidophilus       0.00      0.00      0.00         1
#                                   lactobacillus_salivarius       0.00      0.00      0.00         1
#                                           lactobacillus_sp       0.00      0.00      0.00         1
#                                       legionella_bozemanae       0.00      0.00      0.00         1
#                                        legionella_micdadei       0.00      0.00      0.00         1
#                                     legionella_pneumophila       0.00      0.00      0.00         1
#                                         leptotrichia_wadei       0.00      0.00      0.00         1
#                                     listeria_monocytogenes       0.00      0.00      0.00         2
#                                        methylobacterium_sp       0.00      0.00      0.00         1
#                                     microbacterium_oxydans       0.00      0.00      0.00         1
#                                             micrococcus_sp       0.00      0.00      0.00         1
#                                  moraxella_nonliquefaciens       0.00      0.00      0.00         1
#                                        morganella_morganii       1.00      1.00      1.00         4
#                                        mycobacterium_avium       0.00      0.00      0.00         1
#                                        mycobacterium_bovis       0.00      0.00      0.00         1
#                                    mycobacterium_fortuitum       0.00      0.00      0.00         1
#                                  mycobacterium_haemophilum       0.00      0.00      0.00         1
#                               mycobacterium_intercellulare       0.00      0.00      0.00         1
#                               mycobacterium_intracellulare       0.00      0.00      0.00         1
#                                       mycobacterium_simiae       0.00      0.00      0.00         1
#                                         mycoplasma_hominis       0.00      0.00      0.00         1
#                                      myroides_odoratimimus       0.00      0.00      0.00         1
#                                     neisseria_meningitidis       0.50      1.00      0.67         1
#                                            neisseria_sicca       0.00      0.00      0.00         1
#                                               neisseria_sp       0.00      0.00      0.00         1
#                                      neisseria_zoodegmatis       0.00      0.00      0.00         1
#                                                  no growth       0.12      1.00      0.22        24
#                                         nocardia_abscessus       0.00      0.00      0.00         1
#                                        nocardia_asteroides       0.00      0.00      0.00         1
#                                      nocardia_brasiliensis       0.00      0.00      0.00         1
#                                   nocardia_cyriacigeorgica       0.00      0.00      0.00         1
#                                              olsenella_uli       0.00      0.00      0.00         1
#                                             other bacteria       1.00      1.00      1.00         1
#                                               other fungus       0.00      0.00      0.00         1
#                                             other organism       0.00      0.00      0.00         1
#                                     paenibacillus_polymyxa       0.00      0.00      0.00         1
#                                           paenibacillus_sp       0.00      0.00      0.00         1
#                                     paenibacillus_urinalis       0.00      0.00      0.00         1
#                                        parainfluenza_virus       0.00      0.00      0.00         1
#                                              parvimonas_sp       0.00      0.00      0.00         1
#                                             penicillium_sp       0.00      0.00      0.00         1
#                             peptoniphilus_assacharolyticus       0.00      0.00      0.00         1
#                                        peptoniphilus_harei       0.00      0.00      0.00         2
#                                    peptoniphilus_indolicus       0.00      0.00      0.00         2
#                                   peptoniphilus_lacrimalis       0.00      0.00      0.00         1
#                                           peptoniphilus_sp       0.00      0.00      0.00         2
#                                  peptostreptococcus_micros       0.00      0.00      0.00         1
#                                      peptostreptococcus_sp       0.00      0.00      0.00         1
#                                           plasmodium_ovale       0.00      0.00      0.00         1
#                                     pneumocystis_jirovecii       0.00      0.00      0.00         1
#                              porphyromonas_asaccharolytica       0.00      0.00      0.00         1
#                                           porphyromonas_sp       0.00      0.00      0.00         1
#                                       prevotella_bergensis       0.00      0.00      0.00         1
#                                           prevotella_bivia       0.00      0.00      0.00         1
#                                          prevotella_buccae       0.00      0.00      0.00         1
#                                       prevotella_histicola       0.00      0.00      0.00         1
#                                          prevotella_oralis       0.00      0.00      0.00         1
#                                         prevotella_salivae       0.00      0.00      0.00         1
#                                              prevotella_sp       0.00      0.00      0.00         1
#                                          proteus_mirabilis       1.00      1.00      1.00         8
#                                                 proteus_sp       0.00      0.00      0.00         1
#                                           proteus_vulgaris       1.00      1.00      1.00         6
#                                  providencia_alcalifaciens       0.00      0.00      0.00         1
#                                       providencia_rettgeri       1.00      1.00      1.00         1
#                                             providencia_sp       0.00      0.00      0.00         1
#                                       providencia_stuartii       0.67      1.00      0.80         2
#                                     pseudomonas_aeruginosa       0.86      1.00      0.93        57
#                                    pseudomonas_alcaligenes       0.00      0.00      0.00         1
#                                  pseudomonas_citronellolis       0.00      0.00      0.00         1
#                                    pseudomonas_fluorescens       0.00      0.00      0.00         1
#                                       pseudomonas_otitidis       0.00      0.00      0.00         1
#                                         pseudomonas_putida       0.00      0.00      0.00         1
#                                             pseudomonas_sp       0.00      0.00      0.00         3
#                                               rahnella_spp       0.00      0.00      0.00         1
#                                        ralstonia_pickettii       0.00      0.00      0.00         1
#                                               ralstonia_sp       0.00      0.00      0.00         1
#                                 raoultella_ornithinolytica       1.00      1.00      1.00         1
#                                respiratory_syncytial_virus       0.00      0.00      0.00         1
#                                      rhizobium_radiobacter       0.00      0.00      0.00         1
#                                                rhizopus_sp       0.00      0.00      0.00         1
#                                                  rotavirus       0.00      0.00      0.00         1
#                                   saccharomyces_cerevisiae       0.00      0.00      0.00         1
#                                           salmonella_agona       0.00      0.00      0.00         1
#                                          salmonella_dublin       0.00      0.00      0.00         1
#                                        salmonella_enterica       1.00      1.00      1.00         6
#                                     salmonella_enteritidis       0.00      0.00      0.00         1
#                                      salmonella_heidelberg       0.00      0.00      0.00         1
#                                        salmonella_infantis       0.00      0.00      0.00         1
#                                         salmonella_javiana       0.00      0.00      0.00         1
#                                         salmonella_newport       0.00      0.00      0.00         1
#                                     salmonella_oranienburg       0.00      0.00      0.00         1
#                                        salmonella_soerenga       0.00      0.00      0.00         1
#                                              salmonella_sp       0.00      0.00      0.00         0
#                                         salmonella_stanley       0.00      0.00      0.00         1
#                                          scopulariopsis_sp       0.00      0.00      0.00         1
#                                         serratia_fonticola       0.00      0.00      0.00         1
#                                      serratia_liquefaciens       0.00      0.00      0.00         1
#                                        serratia_marcescens       0.56      1.00      0.71         5
#                                                serratia_sp       0.00      0.00      0.00         2
#                                              shewanella_sp       0.00      0.00      0.00         1
#                                            shigella_boydii       0.00      0.00      0.00         1
#                                             slackia_exigua       0.00      0.00      0.00         1
#                                        sphingobacterium_sp       0.00      0.00      0.00         1
#                                     sphingomonas_koreensis       0.00      0.00      0.00         1
#                                      staphylococcus_aureus       0.85      1.00      0.92        58
#                                 staphylococcus_auricularis       0.00      0.00      0.00         1
#                                     staphylococcus_capitis       1.00      1.00      1.00         4
#                                     staphylococcus_coagneg       0.79      1.00      0.88        11
#                                      staphylococcus_cohnii       0.00      0.00      0.00         1
#                                 staphylococcus_epidermidis       1.00      1.00      1.00        10
#                                staphylococcus_haemolyticus       1.00      1.00      1.00         3
#                                     staphylococcus_hominis       0.50      1.00      0.67         2
#                                 staphylococcus_intermedius       0.00      0.00      0.00         1
#                                 staphylococcus_lugdunensis       0.00      0.00      0.00         5
#                                    staphylococcus_pasteuri       0.00      0.00      0.00         1
#                                    staphylococcus_simulans       0.00      0.00      0.00         1
#                               stenotrophomonas_maltophilia       1.00      1.00      1.00         7
#                                         streptcoccus_bovis       0.00      0.00      0.00         1
#                                   streptcoccus_infantarius       0.00      0.00      0.00         1
#                                   streptococcus_agalactiae       1.00      1.00      1.00         1
#                                    streptococcus_anginosus       0.86      1.00      0.92         6
#                                streptococcus_betahemolytic       0.00      0.00      0.00         2
#                                        streptococcus_canis       0.00      0.00      0.00         1
#                                 streptococcus_dysgalactiae       1.00      1.00      1.00         2
#                                      streptococcus_equinus       0.00      0.00      0.00         1
#                                 streptococcus_gallolyticus       1.00      1.00      1.00         1
#                                     streptococcus_gordonii       0.00      0.00      0.00         1
#                                   streptococcus_halichoeri       0.00      0.00      0.00         1
#                                      streptococcus_milleri       0.00      0.00      0.00         1
#                                        streptococcus_mitis       1.00      1.00      1.00         1
#                                       streptococcus_mutans       0.00      0.00      0.00         1
#                                 streptococcus_nonhemolytic       0.00      0.00      0.00         2
#                                 streptococcus_pasteurianus       0.00      0.00      0.00         1
#                                   streptococcus_pneumoniae       0.36      1.00      0.53         5
#                                   streptococcus_salivarius       0.50      1.00      0.67         1
#                                    streptococcus_sanguinis       0.00      0.00      0.00         2
#                                           streptococcus_sp       0.50      0.67      0.57         3
#                                 streptococcus_vestibularis       0.00      0.00      0.00         1
#                                            streptomyces_sp       0.00      0.00      0.00         1
#                                           strongyloides_sp       0.00      0.00      0.00         1
#                                        trichosporon_asahii       0.00      0.00      0.00         2
#                              trichosporon_mycotoxinivorans       0.00      0.00      0.00         1
# tuberculosis (nos, afb, acid fast bacillus, koch bacillus)       0.00      0.00      0.00         2
#                                       vagococcus_fluvialis       0.00      0.00      0.00         1
#                                        veillonella_parvula       0.00      0.00      0.00         1
#                                             veillonella_sp       0.00      0.00      0.00         1
#                                      wautersiella_falsenii       0.00      0.00      0.00         1
#                                                yeast (nos)       1.00      0.60      0.75         5
#                                    yersinia_enterocolitica       0.00      0.00      0.00         1
#
#                                                   accuracy                           0.60       675
#                                                  macro avg       0.16      0.19      0.17       675
#                                               weighted avg       0.50      0.60      0.53       675

# %%
def predict_organism_name(ord_value):
    # Preprocess the input
    input_vector = vectorizer.transform([ord_value])
    
    # Predict using the trained model
    prediction = model.predict(input_vector)[0]
    
    # Calculate similarity score
    similarity_scores = cosine_similarity(input_vector, X_test).flatten()
    max_similarity_index = np.argmax(similarity_scores)
    max_similarity_score = similarity_scores[max_similarity_index]
    
    return prediction, max_similarity_score

# %%
# Example 1
ord_value = "escherichia coli strain 5"
result, accuracy = predict_organism_name(ord_value)
print(f"Predicted organism name: {result}, Accuracy: {round(accuracy,2)}")
# Out:
# Predicted organism name: escherichia_coli, Accuracy: 1.0

# %%
#Example 2
ord_value = "400,000 ACINETOBACTER BAUMANII STRAIN 2"
result, accuracy = predict_organism_name(ord_value)
print(f"Predicted organism name: {result}, Accuracy: {round(accuracy,2)}")
# Out:
# Predicted organism name: acinetobacter_baumanii, Accuracy: 1.0

# %%
def predict_organism_category(ord_value):
    # Preprocess the input
    input_vector = vectorizer.transform([ord_value])
    
    # Predict using the trained model
    predicted_organism_name = model.predict(input_vector)[0]
    
    # Lookup the organism category
    organism_category = organism_data.loc[organism_data['organism_name'] == predicted_organism_name, 'organism_category'].values[0]
    
    # Calculate similarity score
    similarity_scores = cosine_similarity(input_vector, vectorizer.transform(organism_data['ord_value'])).flatten()
    max_similarity_score = np.max(similarity_scores)
    
    return predicted_organism_name, organism_category, max_similarity_score

def process_input_file(input_file, output_file):
    # Read input file
    input_data = pd.read_csv(input_file)
    
    # Ensure the input column is named 'ord_value'
    if 'ord_value' not in input_data.columns:
        raise ValueError("Input file must contain 'ord_value' column")
    
    # Initialize lists to store results
    predictions = []
    categories = []
    accuracies = []
    
    # Iterate over each ord_value and predict
    for ord_value in input_data['ord_value']:
        prediction, category, accuracy = predict_organism_category(ord_value)
        predictions.append(prediction)
        categories.append(category)
        accuracies.append(accuracy)
    
    # Add results to DataFrame
    input_data['predicted_organism_name'] = predictions
    input_data['predicted_organism_category'] = categories
    input_data['accuracy'] = accuracies
    
    # Write results to output file
    input_data.to_csv(output_file, index=False)

# %%
input_file = 'test.csv'
output_file = 'test_predictions.csv'
process_input_file(input_file, output_file)
